# %%
import cv2
from keras.models import load_model
import numpy as np
from PIL import Image, ImageOps
from random import choice

print("\nYou are about to play rock, paper, scissors with the computer...." 
      "\n\nThe rules are simple and clear:"
        "\n\nRock smashes scissors."
        "\nScissors cut paper."  
        "\nPaper covers rock."
      "\n\nKeep playing until one of you has 3 wins !!!")

name = input("\nPlease give us your name  : ").capitalize()

while True:    
    cap = cv2.VideoCapture(0)
    data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
    c = 0  # counter for computer wins
    p = 0  # counter for player wins
    e = 0  # counter for empty inputs
    d = 0  # counter for draws
    
    while c != 3 and p != 3:
                        
        p0 = choice(['rock', 'paper', 'scissors'])
        p1 = str(p0)
  
        # Load the model
        model = load_model('keras_model.h5', compile = 'False')

        while True:            
            ret, frame = cap.read()
            resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
            image_np = np.array(resized_frame)
            normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
            data[0] = normalized_image
            prediction = model.predict(data)
            cv2.imshow('frame', frame)
            
            # PRESS Q TO CAPTURE IMAGE !!
            
            if prediction[0][0] > 0.7:
                p2 = 'rock'
                print("rock")                            
            elif prediction[0][1] > 0.7:
                p2 = 'paper'
                print("paper")                                
            elif prediction[0][2] > 0.7:
                p2 = 'scissors'
                print("scissors")                
            else:
                p2 = ""
                print("nothing")
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break                                 
                       
    
        print('\nComputer : ', p1, f'\n{name} : ', p2)
        
        if p2 != "":
            p3 = str(p2)
            if p3 == 'rock' or p3 == 'paper' or p3 == 'scissors':
                if p1 == p3:
                    d += 1
                    print("\nIt's a draw!")
                elif p1 == "rock" and p3 == "scissors":
                    c += 1
                    print("\nComputer wins..")
                elif p1 == "paper" and p3 == "rock":
                    c += 1
                    print("\nComputer wins..")
                elif p1 == "scissors" and p3 == "paper":
                    c += 1
                    print("\nComputer wins..")
                else:
                    p += 1
                    print(f"\n{name} wins !!!")
        else:
            e += 1
            print("\nAh we probably got nothing as input, please retype !")


    print("\nTotal Computer wins : ", c)
    print("Total Player wins     : ", p)
    print("Total Draws           : ", d)
    print("Empty Inputs          : ", e)


    if c > p:
        print("\nCOMPUTER IS THE FINAL WINNER :( ")
    else:    
        print(f"\n{name.upper()} IS THE FINAL WINNER !!! ")                                
    
    play_again = input("\nWanna play again? (y/n): ")
    if play_again.lower() != "y" and play_again.lower() != "yes":
        break
    else:
        # After the loop release the cap object
        cap.release()
        #Destroy all the windows
        cv2.destroyAllWindows()
# Out:
# You are about to play rock, paper, scissors with the computer....
#
# The rules are simple and clear:
#
# Rock smashes scissors.
# Scissors cut paper.
# Paper covers rock.
#
# Keep playing until one of you has 3 wins !!!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# rock
# rock
# rock
# rock
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# rock
# nothing
# rock
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# rock
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# nothing
# nothing
# paper
# paper
# paper
# paper
#
# Computer :  rock
# John :  paper
#
# John wins !!!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# nothing
# nothing
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# nothing
# nothing
# scissors
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# rock
# rock
# rock
# rock
# rock
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# nothing
# nothing
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
#
# Computer :  scissors
# John :  rock
#
# John wins !!!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
# rock
#
# Computer :  scissors
# John :  rock
#
# John wins !!!
#
# Total Computer wins :  0
# Total Player wins     :  3
# Total Draws           :  0
# Empty Inputs          :  0
#
# JOHN IS THE FINAL WINNER !!!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# rock
# rock
# rock
# rock
# rock
# nothing
# nothing
# scissors
# scissors
# scissors
# scissors
# nothing
# scissors
# scissors
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# paper
# nothing
# rock
# nothing
# rock
# nothing
# nothing
# nothing
# nothing
# nothing
# scissors
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# paper
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# scissors
# scissors
# nothing
# nothing
# nothing
# nothing
# scissors
# scissors
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# scissors
# scissors
# scissors
# scissors
# nothing
# scissors
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# scissors
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# nothing
# nothing
# scissors
# scissors
# scissors
# scissors
# nothing
# paper
# nothing
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
#
# Computer :  scissors
# John :  scissors
#
# It's a draw!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
#
# Computer :  paper
# John :  scissors
#
# John wins !!!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
#
# Computer :  rock
# John :  scissors
#
# Computer wins..
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
#
# Computer :  scissors
# John :  scissors
#
# It's a draw!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
#
# Computer :  rock
# John :  scissors
#
# Computer wins..
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# scissors
#
# Computer :  paper
# John :  scissors
#
# John wins !!!
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# nothing
# scissors
# scissors
# scissors
# scissors
# scissors
# scissors
# nothing
# nothing
# scissors
#
# Computer :  rock
# John :  scissors
#
# Computer wins..
#
# Total Computer wins :  3
# Total Player wins     :  2
# Total Draws           :  2
# Empty Inputs          :  0
#
# COMPUTER IS THE FINAL WINNER :(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
#      93 else:
#      94     print(f"\n{name.upper()} IS THE FINAL WINNER !!! ")
# ---> 96 play_again = input("\nWanna play again? (y/n): ")
#      97 if play_again.lower() != "y" and play_again.lower() != "yes":
#      98     break
#
# File ~\anaconda3\envs\image\envs\teachable\lib\site-packages\ipykernel\kernelbase.py:1044, in Kernel.raw_input(self, prompt)
#    1040 if not self._allow_stdin:
#    1041     raise StdinNotImplementedError(
#    1042         "raw_input was called, but this frontend does not support input requests."
#    1043     )
# -> 1044 return self._input_request(
#    1045     str(prompt),
#    1046     self._parent_ident["shell"],
#    1047     self.get_parent("shell"),
#    1048     password=False,
#    1049 )
#
# File ~\anaconda3\envs\image\envs\teachable\lib\site-packages\ipykernel\kernelbase.py:1089, in Kernel._input_request(self, prompt, ident, parent, password)
#    1086             break
#    1087 except KeyboardInterrupt:
#    1088     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1089     raise KeyboardInterrupt("Interrupted by user") from None
#    1090 except Exception:
#    1091     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
